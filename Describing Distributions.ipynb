# %% [markdown]
# # Describing Distributions
#
# - Robert Yonce
# - 5/8/23

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from scipy import stats

# %%
# Import Data

df = pd.read_csv('data-7.csv')
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
#    Reflux_esophagitis Asthma     Services  Initial_days  TotalCharge  \
# 0                   0      1   Blood Work     10.585770  3726.702860
# 1                   1      0  Intravenous     15.129562  4193.190458
# 2                   0      0   Blood Work      4.772177  2434.234222
# 3                   1      1   Blood Work      1.714879  2127.830423
# 4                   0      0      CT Scan      1.254807  2113.073274
#
#    Additional_charges
# 0        17939.403420
# 1        17612.998120
# 2        17505.192460
# 3        12993.437350
# 4         3716.525786
#
# [5 rows x 32 columns]

# %% [markdown]
# ## The Features to Analyze:
# - VitD_levels
# - Doc_visits
# - TotalCharge

# %% [markdown]
# ## VitD_Levels Graphs

# %%
# Histogram with KDE

sns.histplot(data=df, x='VitD_levels', stat='density', kde = True);

# %%
# Histogram with Mean and Median

col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %%
# Histogram with STD and Highlight range

col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
kurt1 = stats.kurtosis(df['VitD_levels'], fisher = False)
kurt1
# Out:
# 3.013147515833447

# %% [markdown]
# ### Questions

# %% [markdown]
# - Is it Discrete or Continuous?
#     - Discrete

# %% [markdown]
# - Does it have a skew? If so, which direction (+/-)
#     - No skew

# %% [markdown]
# - What type of kurtosis does it display?
#     - Mesokurtic

# %% [markdown]
# ## Doc_visits Graphs

# %%
# Histogram with KDE

sns.histplot(data=df, x='Doc_visits', stat='density', kde = True);

# %%
# Histogram with Mean and Median

col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %%
# Histogram with STD and Highlight range

col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
kurt2 = stats.kurtosis(df['Doc_visits'], fisher = False)
kurt2
# Out:
# 2.9919958083381206

# %% [markdown]
# ### Questions

# %% [markdown]
# - Is it Discrete or Continuous?
#     - Continuous

# %% [markdown]
# - Does it have a skew? If so, which direction (+/-)
#     - No this data does not

# %% [markdown]
# - What type of kurtosis does it display?
#     - Mesokurtic

# %% [markdown]
# ## TotalCharge Graphs

# %%
# Histogram with KDE

sns.histplot(data=df, x='TotalCharge', stat='density', kde = True);

# %%
# Histogram with Mean and Median

col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %%
# Histogram with STD and Highlight range

col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
kurt3 = stats.kurtosis(df['TotalCharge'], fisher = False)
kurt3
# Out:
# 3.2650077463439384

# %% [markdown]
# ### Questions

# %% [markdown]
# - Is it Discrete or Continuous?
#     - Continuous

# %% [markdown]
# - Does it have a skew? If so, which direction (+/-)
#     - Yes, + skew

# %% [markdown]
# - What type of kurtosis does it display?
#     - Leptokurtic
